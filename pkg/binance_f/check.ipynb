# %%
from module_analData import Analysis

day = Analysis(interval ='1d')
day.get_plot(day.rsi)

# %%
day.stochastic_oscillator
# Out:
# (64.96580905207855, 29053.533333333336, 28844.72666666667)

# %%
day.get_plot(day.cci)

# %%
day.get_plot(day.average_directional_index)
